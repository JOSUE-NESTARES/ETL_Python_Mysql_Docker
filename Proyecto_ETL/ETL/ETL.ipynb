# %%
import pandas as pd
import sqlalchemy as db
from sqlalchemy import text
import pandas as pd

# %%
engine = db.create_engine("mysql://root:root@127.0.0.1:3310/db_movies_netflix_transact")
conn = engine.connect()

# %% [markdown]
# # Cargamos datos a la dimension Movie

# %%
query = """
SELECT 
    movie.movieID as movieID, movie.movieTitle as title, movie.releaseDate as releaseDate, 
    gender.name as gender , person.name as participantName, participant.participantRole as roleparticipant 
FROM movie 
INNER JOIN participant 
ON movie.movieID=participant.movieID
INNER JOIN person
ON person.personID = participant.personID
INNER JOIN movie_gender 
ON movie.movieID = movie_gender.movieID
INNER JOIN gender 
ON movie_gender.genderID = gender.genderID
"""

# %%
movies_data=pd.read_sql(query, con=conn) 
movies_data["movieID"]=movies_data["movieID"].astype('int')
movies_data
# Out:
#     movieID            title releaseDate     gender          participantName  \
# 0  80192187  Triple Frontier  2019-04-12     Action     Joseph Chavez Pineda
# 1  80210920       The Mother  2023-01-05      Drama  Maria Alejandra Navarro
# 2  81157374              Run  2021-05-21  Adventure     aria Lopez Gutierrez
#
#   roleparticipant
# 0           Actor
# 1           Actor
# 2        Director

# %%
movies_award=pd.read_csv("./data/Awards_movie.csv")
movies_award["movieID"]=movies_award["movieID"].astype('int')
movies_award.rename(columns={"Aware":"Award"}, inplace=True)
movies_award
# Out:
#     movieID  IdAward   Award
# 0  80210920        0   Oscar
# 1  81157374        1  Grammy
# 2  80192187        2   Oscar

# %%
movie_data=pd.merge(movies_data,movies_award, left_on="movieID", right_on="movieID")
movie_data
# Out:
#     movieID            title releaseDate     gender          participantName  \
# 0  80192187  Triple Frontier  2019-04-12     Action     Joseph Chavez Pineda
# 1  80210920       The Mother  2023-01-05      Drama  Maria Alejandra Navarro
# 2  81157374              Run  2021-05-21  Adventure     aria Lopez Gutierrez
#
#   roleparticipant  IdAward   Award
# 0           Actor        2   Oscar
# 1           Actor        0   Oscar
# 2        Director        1  Grammy

# %%
engine = db.create_engine("mysql://root:root@127.0.0.1:3310/dw_netflix")
conn = engine.connect()

# %%
movie_data = movie_data.rename(columns={'releaseDate': 'releaseMovie', 'Award': 'awardMovie'})

# %%
movie_data = movie_data.drop(columns=['IdAward'])

# %%
movie_data.to_sql('dimMovie',conn,if_exists='append', index=False)
# Out:
# 3

# %% [markdown]
# # Cargamos datos a la dimension USER

# %%
users = pd.read_csv("./data/users.csv", sep='|')
users
# Out:
#       idUser     username      country subscription
# 0    1002331      user123          USA      Premium
# 1    1002332  gamerGirl97       Canada        Basic
# 2    1002333   techMaster           UK      Premium
# 3    1002334    soccerFan       Brazil        Basic
# 4    1002335    travelBug    Australia      Premium
# 5    1002336   musicLover       France        Basic
# 6    1002337     foodie88        Italy      Premium
# 7    1002338   bookWorm23      Germany        Basic
# 8    1002339  fitnessJunk       Mexico      Premium
# 9   10023310    movieBuff        Japan        Basic
# 10  10023311  artAficiona        Spain      Premium
# 11  10023312   petLover99  Netherlands        Basic
# 12  10023313  fashionista   SouthKorea      Premium
# 13  10023314  codingNinja        India        Basic
# 14  10023315  natureLover       Norway      Premium
# 15  10023316  coffeeAddct     Colombia        Basic
# 16  10023317     beachBum      Bahamas      Premium
# 17  10023318  skiEnthusst  Switzerland        Basic
# 18  10023319     homeChef   NewZealand      Premium
# 19  10023320   yogiMaster     Thailand        Basic

# %%
users = users.rename(columns={'idUser': 'userID'})
users
# Out:
#       userID     username      country subscription
# 0    1002331      user123          USA      Premium
# 1    1002332  gamerGirl97       Canada        Basic
# 2    1002333   techMaster           UK      Premium
# 3    1002334    soccerFan       Brazil        Basic
# 4    1002335    travelBug    Australia      Premium
# 5    1002336   musicLover       France        Basic
# 6    1002337     foodie88        Italy      Premium
# 7    1002338   bookWorm23      Germany        Basic
# 8    1002339  fitnessJunk       Mexico      Premium
# 9   10023310    movieBuff        Japan        Basic
# 10  10023311  artAficiona        Spain      Premium
# 11  10023312   petLover99  Netherlands        Basic
# 12  10023313  fashionista   SouthKorea      Premium
# 13  10023314  codingNinja        India        Basic
# 14  10023315  natureLover       Norway      Premium
# 15  10023316  coffeeAddct     Colombia        Basic
# 16  10023317     beachBum      Bahamas      Premium
# 17  10023318  skiEnthusst  Switzerland        Basic
# 18  10023319     homeChef   NewZealand      Premium
# 19  10023320   yogiMaster     Thailand        Basic

# %%
users.to_sql('dimUser',conn,if_exists='append', index=False)
# Out:
# 20

# %% [markdown]
# # Cargamos datos a la tabla de hechos

# %%
users_id=users["userID"]
movies_id=movies_data["movieID"]

# %%
watchs_data=pd.merge(users_id,movies_id, how="cross")
watchs_data
# Out:
#       userID   movieID
# 0    1002331  80192187
# 1    1002331  80210920
# 2    1002331  81157374
# 3    1002332  80192187
# 4    1002332  80210920
# 5    1002332  81157374
# 6    1002333  80192187
# 7    1002333  80210920
# 8    1002333  81157374
# 9    1002334  80192187
# 10   1002334  80210920
# 11   1002334  81157374
# 12   1002335  80192187
# 13   1002335  80210920
# 14   1002335  81157374
# 15   1002336  80192187
# 16   1002336  80210920
# 17   1002336  81157374
# 18   1002337  80192187
# 19   1002337  80210920
# 20   1002337  81157374
# 21   1002338  80192187
# 22   1002338  80210920
# 23   1002338  81157374
# 24   1002339  80192187
# 25   1002339  80210920
# 26   1002339  81157374
# 27  10023310  80192187
# 28  10023310  80210920
# 29  10023310  81157374
# 30  10023311  80192187
# 31  10023311  80210920
# 32  10023311  81157374
# 33  10023312  80192187
# 34  10023312  80210920
# 35  10023312  81157374
# 36  10023313  80192187
# 37  10023313  80210920
# 38  10023313  81157374
# 39  10023314  80192187
# 40  10023314  80210920
# 41  10023314  81157374
# 42  10023315  80192187
# 43  10023315  80210920
# 44  10023315  81157374
# 45  10023316  80192187
# 46  10023316  80210920
# 47  10023316  81157374
# 48  10023317  80192187
# 49  10023317  80210920
# 50  10023317  81157374
# 51  10023318  80192187
# 52  10023318  80210920
# 53  10023318  81157374
# 54  10023319  80192187
# 55  10023319  80210920
# 56  10023319  81157374
# 57  10023320  80192187
# 58  10023320  80210920
# 59  10023320  81157374

# %%
import random
from datetime import datetime, timedelta
import random

def gen_rating():
    # Generar un número aleatorio entre 0 y 5 con 1 solo decimal
    numero_aleatorio = round(random.uniform(0, 5), 1)
    # Mostrar el número aleatorio
    return numero_aleatorio

def gen_timestamp():
    # Generar un timestamp aleatorio dentro de un rango específico
    start_date = datetime(2024, 12, 15)
    end_date = datetime(2025, 1, 15)

    # Calcular un valor aleatorio entre start_date y end_date
    random_date = start_date + timedelta(seconds=random.randint(0, int((end_date - start_date).total_seconds())))

    # Mostrar el timestamp aleatorio
    return random_date

# %%
watchs_data["rating"]=watchs_data["movieID"].apply(lambda x: gen_rating())
watchs_data["timestamp"]=watchs_data["userID"].apply(lambda x: gen_timestamp())

# %%
watchs_data
# Out:
#       userID   movieID  rating           timestamp
# 0    1002331  80192187     3.8 2025-01-01 01:23:33
# 1    1002331  80210920     0.2 2025-01-09 11:44:15
# 2    1002331  81157374     1.1 2025-01-04 18:07:17
# 3    1002332  80192187     4.5 2024-12-16 21:05:46
# 4    1002332  80210920     0.5 2024-12-17 08:31:44
# 5    1002332  81157374     4.1 2024-12-17 13:13:53
# 6    1002333  80192187     2.0 2024-12-27 10:33:06
# 7    1002333  80210920     3.8 2025-01-01 18:40:53
# 8    1002333  81157374     2.3 2024-12-22 23:09:51
# 9    1002334  80192187     0.7 2024-12-26 20:21:22
# 10   1002334  80210920     3.3 2025-01-06 22:24:02
# 11   1002334  81157374     3.7 2025-01-10 06:03:39
# 12   1002335  80192187     4.9 2025-01-08 12:37:43
# 13   1002335  80210920     1.1 2025-01-09 15:33:22
# 14   1002335  81157374     1.0 2024-12-25 21:10:01
# 15   1002336  80192187     2.7 2024-12-22 18:38:26
# 16   1002336  80210920     1.7 2025-01-09 07:11:16
# 17   1002336  81157374     2.6 2025-01-03 19:57:56
# 18   1002337  80192187     1.8 2025-01-11 13:58:44
# 19   1002337  80210920     3.7 2025-01-07 12:29:28
# 20   1002337  81157374     0.1 2025-01-11 13:26:13
# 21   1002338  80192187     3.4 2025-01-01 06:04:36
# 22   1002338  80210920     0.7 2025-01-01 10:59:25
# 23   1002338  81157374     1.8 2024-12-30 15:11:44
# 24   1002339  80192187     0.5 2025-01-08 09:54:45
# 25   1002339  80210920     3.1 2024-12-28 13:32:05
# 26   1002339  81157374     0.4 2024-12-29 21:59:43
# 27  10023310  80192187     2.3 2025-01-07 19:14:06
# 28  10023310  80210920     3.9 2025-01-07 17:11:44
# 29  10023310  81157374     3.0 2024-12-17 10:07:14
# 30  10023311  80192187     0.2 2024-12-25 10:01:27
# 31  10023311  80210920     4.5 2024-12-28 20:24:35
# 32  10023311  81157374     4.4 2024-12-23 21:46:12
# 33  10023312  80192187     0.8 2024-12-16 21:46:45
# 34  10023312  80210920     0.9 2025-01-01 02:12:35
# 35  10023312  81157374     2.5 2025-01-04 10:35:00
# 36  10023313  80192187     2.8 2024-12-29 10:45:02
# 37  10023313  80210920     1.0 2024-12-31 23:30:02
# 38  10023313  81157374     1.8 2024-12-16 16:56:59
# 39  10023314  80192187     1.1 2024-12-18 01:06:23
# 40  10023314  80210920     2.8 2025-01-13 16:32:11
# 41  10023314  81157374     2.3 2025-01-01 09:08:52
# 42  10023315  80192187     3.7 2025-01-14 07:49:50
# 43  10023315  80210920     1.7 2025-01-04 21:36:05
# 44  10023315  81157374     1.0 2025-01-10 21:07:31
# 45  10023316  80192187     4.7 2025-01-10 06:24:35
# 46  10023316  80210920     4.6 2024-12-29 15:45:11
# 47  10023316  81157374     0.8 2024-12-26 14:43:10
# 48  10023317  80192187     1.7 2025-01-11 00:52:42
# 49  10023317  80210920     2.0 2025-01-12 23:07:01
# 50  10023317  81157374     4.7 2024-12-19 19:32:31
# 51  10023318  80192187     4.1 2024-12-22 22:03:53
# 52  10023318  80210920     3.7 2024-12-20 19:24:46
# 53  10023318  81157374     0.9 2024-12-28 13:45:12
# 54  10023319  80192187     0.5 2025-01-09 19:57:15
# 55  10023319  80210920     3.2 2024-12-15 09:38:13
# 56  10023319  81157374     1.5 2024-12-17 04:36:11
# 57  10023320  80192187     4.5 2025-01-03 16:24:20
# 58  10023320  80210920     1.9 2024-12-28 21:52:17
# 59  10023320  81157374     5.0 2024-12-31 00:30:41

# %%
# Cargamos tabla de hechos
watchs_data.to_sql("FactWatchs", conn, if_exists='append', index=False)
# Out:
# 60

# %%
### SET FOREIGN_KEY_CHECKS = 0;
### SET FOREIGN_KEY_CHECKS = 1;
